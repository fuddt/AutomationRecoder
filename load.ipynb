# %%
# Importing the necessary module to read the pickle file
import pickle
import pyautogui
import time
# Read the content of the uploaded pickle file
pickle_file_path = 'events.pkl'
with open(pickle_file_path, 'rb') as f:
    events_data_pickle = pickle.load(f)
events_data_pickle
#
# Out:
# [('mouse_move', 2446.5, 996.8828125),
#  ('mouse_move', 2445.625, 997.171875),
#  ('mouse_move', 2444.75, 997.4609375),
#  ('mouse_move', 2444.51953125, 997.6875),
#  ('mouse_move', 2444.2890625, 997.6875),
#  ('mouse_move', 2443.828125, 997.6875),
#  ('mouse_move', 2442.953125, 997.6875),
#  ('mouse_move', 2440.5703125, 997.2109375),
#  ('mouse_move', 2435.1484375, 996.00390625),
#  ('mouse_move', 2426.671875, 994.69921875),
#  ('mouse_move', 2409.03515625, 991.875),
#  ('mouse_move', 2395.9765625, 990.5),
#  ('mouse_move', 2356.1875, 988.40234375),
#  ('mouse_move', 2343.12890625, 988.40234375),
#  ('mouse_move', 2325.4921875, 988.40234375),
#  ('mouse_move', 2252.2890625, 987.1171875),
#  ('mouse_move', 2224.8125, 983.5703125),
#  ('mouse_move', 2132.26171875, 975.40234375),
#  ('mouse_move', 2113.58203125, 974.68359375),
#  ('mouse_move', 2102.05078125, 974.68359375),
#  ('mouse_move', 2101.57421875, 972.30078125),
#  ('mouse_move', 2089.28125, 972.30078125),
# ...

# %%
events_data_pickle[100:]
# Out:
# [('mouse_move', 1121.50390625, 738.7578125),
#  ('mouse_move', 1124.234375, 726.46484375),
#  ('mouse_move', 1126.7578125, 719.515625),
#  ('mouse_move', 1127.9609375, 714.09375),
#  ('mouse_move', 1132.66796875, 704.0),
#  ('mouse_move', 1134.23046875, 700.8671875),
#  ('mouse_move', 1140.33203125, 690.69140625),
#  ('mouse_move', 1143.11328125, 687.3515625),
#  ('mouse_move', 1145.72265625, 685.26171875),
#  ('mouse_move', 1154.65234375, 675.640625),
#  ('mouse_move', 1158.8671875, 672.0234375),
#  ('mouse_move', 1167.53515625, 666.01953125),
#  ('mouse_move', 1170.87109375, 663.79296875),
#  ('mouse_move', 1174.9453125, 661.4609375),
#  ('mouse_move', 1183.5234375, 657.5),
#  ('mouse_move', 1187.41796875, 655.828125),
#  ('mouse_move', 1205.05078125, 650.88671875),
#  ('mouse_move', 1213.5234375, 648.9296875),
#  ('mouse_move', 1224.28515625, 646.23828125),
#  ('mouse_move', 1228.94140625, 644.48828125),
#  ('mouse_move', 1233.59765625, 642.73828125),
# ...

# %%
import pyautogui

# サンプルイベントデータ
sample_event = ('mouse_click', 1241.046875, 638.76953125, '<Button.left: ((1, 2, 6), 0)>', 'double_click')

# イベントタイプを取得
event_type = sample_event[0]

if event_type == 'mouse_click':
    x, y, button, action = sample_event[1], sample_event[2], sample_event[3], sample_event[4]
    # Buttonオブジェクトを文字列に変換（この部分は状況により調整が必要かもしれません）
    button_str = str(button).split(':')[0].split('.')[1].lower()

    if action == 'double_click':
        pyautogui.doubleClick(x=x, y=y)  # ダブルクリックを模倣

# 処理完了メッセージ
print("Event has been successfully replicated.")
# Out:
# Event has been successfully replicated.
